# %%
#import necessary packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load data set
data = pd.read_csv("Yerevan-Hotels.csv")

# %%
data.head(500)
# Out:
#                          Hotel Names  Star Rating  Rating Free Parking  \
# 0                       Kenut Hostel          NaN     9.7          Yes
# 1                      Kantar Hostel          NaN     9.3          Yes
# 2                 Sweet Sleep hostel          NaN     9.5          Yes
# 3    Royal Boutique Hotel on Kievyan          NaN     7.4          Yes
# 4                         Areg Hotel          3.0     8.2           No
# ..                               ...          ...     ...          ...
# 115       Radisson BLU Hotel Yerevan          5.0     8.5          Yes
# 116           Bourbon Boutique Hotel          3.0     9.1           No
# 117         Messier 53 Hotel Yerevan          4.0     8.9          Yes
# 118            Vertoni Hotel Yerevan          NaN     9.5           No
# 119                   14 Floor Hotel          NaN     8.6          Yes
#
#     Fitness Centre Spa and Wellness Centre Airport Shuttle  Staff  Facilities  \
# ...

# %% [raw]
# Here about the description of the columns:
#
# Hotel Names: The names of various hotels or accommodations.
#
# Star Rating: The rating system typically used to indicate the quality or level of luxury of a hotel, often ranging from 1 to 5 stars.
#
# Rating: The overall customer rating or satisfaction score of the hotel, often based on reviews or surveys.
#
# Free Parking: Indicates whether the hotel provides complimentary parking facilities for guests.
#
# Fitness Centre: Specifies whether the hotel has a gym or fitness center available for guests.
#
# Spa and Wellness Centre: Indicates if the hotel offers spa services and wellness facilities.
#
# Airport Shuttle: Specifies whether the hotel provides transportation to and from the airport for guests.
#
# Staff: Refers to the quality and friendliness of the hotel staff.
#
# Facilities: Describes the range and quality of amenities available at the hotel.
#
# Location: Refers to the convenience and desirability of the hotel's location.
#
# Comfort: Reflects the overall comfort level of the rooms and bedding.
#
# Cleanliness: Indicates the cleanliness and hygiene standards of the hotel.
#
# Price Per Day ($): The cost of staying at the hotel (2 adults) per day (in dollars in this case).

# %%
#find shape of data
data.shape
# Out:
# (120, 13)

# %%
#Check if columns names have spaces
data.columns
# Out:
# Index(['Hotel Names', 'Star Rating', 'Rating', 'Free Parking',
#        'Fitness Centre', 'Spa and Wellness Centre', 'Airport Shuttle', 'Staff',
#        'Facilities', 'Location', 'Comfort', 'Cleanliness', 'Price Per Day($)'],
#       dtype='object')

# %% [raw]
# In this columns names does not have spaces

# %%
# Dropping the 'Column_to_drop' column
data = data.drop(columns=['Hotel Names'])

# %%
#check data types in data set
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Star Rating              79 non-null     float64
#  1   Rating                   115 non-null    float64
#  2   Free Parking             120 non-null    object
#  3   Fitness Centre           120 non-null    object
#  4   Spa and Wellness Centre  120 non-null    object
#  5   Airport Shuttle          120 non-null    object
#  6   Staff                    115 non-null    float64
#  7   Facilities               115 non-null    float64
#  8   Location                 115 non-null    float64
#  9   Comfort                  115 non-null    float64
#  10  Cleanliness              115 non-null    float64
#  11  Price Per Day($)         120 non-null    float64
# dtypes: float64(8), object(4)
# memory usage: 11.4+ KB

# %%
#check null values
null_counts = data.isnull().sum()
null_counts
# Out:
# Star Rating                41
# Rating                      5
# Free Parking                0
# Fitness Centre              0
# Spa and Wellness Centre     0
# Airport Shuttle             0
# Staff                       5
# Facilities                  5
# Location                    5
# Comfort                     5
# Cleanliness                 5
# Price Per Day($)            0
# dtype: int64

# %%
# Plot null values the line chart using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(x=null_counts.index, y=null_counts.values, marker='o')
plt.title('Before Null Value Count for Each Column')
plt.xlabel('Columns')
plt.ylabel('Null Value Count')
plt.grid(True)
plt.show()

# %% [markdown]
# Here we only have 120 rows therefore we can not null value rows.In this case we use mean method to handle null values.

# %%
# Replace NaN values in the "Star Rating" column with the median of that column
median_star_rating = data['Star Rating'].median()
data.fillna({'Star Rating':median_star_rating},inplace=True)

# %%
# Replace NaN values in the "Rating" column with the median of that column
median_rating = data['Rating'].median()
data.fillna({'Rating':median_rating},inplace=True)

# %%
# Replace NaN values in the "Staff" column with the median of that column
median_Staff = data['Staff'].median()
data.fillna({'Staff':median_Staff},inplace=True)

# %%
# Replace NaN values in the "Facilities" column with the median of that column
median_Facilities = data['Facilities'].median()
data.fillna({'Facilities':median_Facilities},inplace=True)

# %%
# Replace NaN values in the "Location" column with the median of that column
median_Location = data['Location'].median()
data.fillna({'Location':median_Location},inplace=True)

# %%
# Replace NaN values in the "Comfort" column with the median of that column
median_Comfort = data['Comfort'].median()
data.fillna({'Comfort':median_Comfort},inplace=True)

# %%
# Replace NaN values in the "Cleanliness" column with the median of that column
median_Cleanliness = data['Cleanliness'].median()
data.fillna({'Cleanliness':median_Cleanliness},inplace=True)

# %%
data.head()
# Out:
#    Star Rating  Rating Free Parking Fitness Centre Spa and Wellness Centre  \
# 0          4.0     9.7          Yes             No                      No
# 1          4.0     9.3          Yes             No                      No
# 2          4.0     9.5          Yes             No                      No
# 3          4.0     7.4          Yes             No                      No
# 4          3.0     8.2           No             No                      No
#
#   Airport Shuttle  Staff  Facilities  Location  Comfort  Cleanliness  \
# 0              No    9.9         9.8       8.8      9.7          9.8
# 1             Yes    9.7         9.4       9.7      9.2          9.2
# 2              No    9.8         9.5       8.9      9.4          9.5
# 3             Yes    8.1         7.3       8.3      7.5          7.8
# 4              No    9.1         8.0       8.3      8.1          8.2
#
#    Price Per Day($)
# 0              30.0
# 1              15.0
# 2              20.0
# ...

# %%
#check after handle null values
null_counts = data.isnull().sum()
null_counts
# Out:
# Star Rating                0
# Rating                     0
# Free Parking               0
# Fitness Centre             0
# Spa and Wellness Centre    0
# Airport Shuttle            0
# Staff                      0
# Facilities                 0
# Location                   0
# Comfort                    0
# Cleanliness                0
# Price Per Day($)           0
# dtype: int64

# %%
# Plot null values the line chart using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(x=null_counts.index, y=null_counts.values, marker='o',color='red')
plt.title('Before Null Value Count for Each Column')
plt.xlabel('Columns')
plt.ylabel('Null Value Count')
plt.grid(True)
plt.show()

# %%
#Check Duplicated values
data.duplicated().sum()
# Out:
# 0

# %% [raw]
# In this data set we have not duplicated values.

# %%
#check columns have invalid valus

# Define validation rules
def is_valid_star_rating(x):
    numeric_x = pd.to_numeric(x, errors='coerce')
    return numeric_x.between(0, 5)

def is_valid_rating(x):
    numeric_x = pd.to_numeric(x, errors='coerce')
    return numeric_x.between(0.0, 10.0)

def is_valid_yes_no(x):
    return x.isin(['Yes', 'No'])


validation_rules = {
    'Star Rating': is_valid_star_rating,
    'Rating': is_valid_rating,
    'Free Parking': is_valid_yes_no,
    'Fitness Centre': is_valid_yes_no,
    'Spa and Wellness Centre': is_valid_yes_no,
    'Airport Shuttle': is_valid_yes_no,
    'Staff': is_valid_rating,
    'Facilities': is_valid_rating,
    'Location': is_valid_rating,
    'Comfort': is_valid_rating,
    'Cleanliness': is_valid_rating
}

# Function to check invalid values for each column based on defined rules
def check_invalid_values(data, rules):
    invalid_counts = {}
    for column, rule in rules.items():
        if column in data.columns:
            invalid_mask = ~rule(data[column])
            invalid_count = invalid_mask.sum()
            invalid_counts[column] = invalid_count
            print(f"Number of invalid values in {column} -----> {invalid_count}")

    return invalid_counts



# Check invalid values
invalid_counts = check_invalid_values(data, validation_rules)
# Out:
# Number of invalid values in Star Rating -----> 0
# Number of invalid values in Rating -----> 0
# Number of invalid values in Free Parking -----> 0
# Number of invalid values in Fitness Centre -----> 0
# Number of invalid values in Spa and Wellness Centre -----> 0
# Number of invalid values in Airport Shuttle -----> 0
# Number of invalid values in Staff -----> 0
# Number of invalid values in Facilities -----> 0
# Number of invalid values in Location -----> 0
# Number of invalid values in Comfort -----> 0
# Number of invalid values in Cleanliness -----> 0

# %%
# Plotting the line chart
plt.figure(figsize=(10, 6))
plt.plot(list(invalid_counts.keys()), list(invalid_counts.values()), marker='o',color ='green')
plt.title('Number of Invalid Values in Each Column')
plt.xlabel('Columns')
plt.ylabel('Number of Invalid Values')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Check outliers
# Extracting numeric columns
numeric_columns = data.select_dtypes(include=['float64', 'int64']).columns

# Create box plots for each numeric column
plt.figure(figsize=(15, 10))
for i, column in enumerate(numeric_columns, 1):
    plt.subplot(3, 4, i)  # Adjust the subplot grid size based on the number of columns
    sns.boxplot(data[column])
    plt.title(f'Box Plot of {column}')
    plt.tight_layout()

plt.show()

# %%
#check statistics
data.describe()
# Out:
#        Star Rating      Rating       Staff  Facilities    Location  \
# count   120.000000  120.000000  120.000000  120.000000  120.000000
# mean      3.850000    8.799167    9.267500    8.767500    8.912500
# std       0.559862    0.758536    0.523428    0.887936    0.778121
# min       2.000000    5.000000    7.500000    2.500000    7.000000
# 25%       4.000000    8.500000    9.100000    8.400000    8.400000
# 50%       4.000000    8.900000    9.400000    8.900000    8.900000
# 75%       4.000000    9.300000    9.600000    9.300000    9.600000
# max       5.000000   10.000000   10.000000   10.000000   10.000000
#
#           Comfort  Cleanliness  Price Per Day($)
# count  120.000000   120.000000        120.000000
# mean     8.943333     8.943333         77.200000
# std      0.729422     0.757454         61.391203
# min      5.000000     5.000000          6.000000
# 25%      8.700000     8.700000         40.000000
# 50%      9.100000     9.100000         62.500000
# ...

# %%
stat_data ={
    'column' : ['Star Rating','Rating','Staff','Facilities','Location','Comfort','Cleanliness',	'Price Per Day($)'],
    'mean' :[3.850000,8.799167,9.267500	,8.767500,8.912500,8.943333,8.943333,77.200000],
    'std':[0.559862,0.758536,0.523428,0.887936,0.778121,0.729422,0.757454,61.391203]
}
df = pd.DataFrame(stat_data)

# %%
# Setting figure size
plt.figure(figsize=(10, 6))

# Plotting bar graph for mean values
plt.bar(df['column'], df['mean'], capsize=5, color='red', alpha=0.7)

# Adding labels and title
plt.xlabel('Columns')
plt.ylabel('Mean Value')
plt.title('Mean Distribution')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
# Setting figure size
plt.figure(figsize=(10, 6))

# Plotting bar graph for mean values
plt.bar(df['column'], df['std'], capsize=5, color='skyblue', alpha=0.7)

# Adding labels and title
plt.xlabel('Columns')
plt.ylabel('std Value')
plt.title('Std Distribution')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
# Plotting value counts for each column
for column in data.columns:
    plt.figure(figsize=(10, 6))
    
    if data[column].dtype == 'object':  # Categorical data
        data[column].value_counts().plot(kind='bar')
        plt.title(f'Value Counts for {column}')
        plt.xlabel(column)
        plt.ylabel('Counts')
    else:  # Numerical data
        data[column].plot(kind='hist', bins=10)
        plt.title(f'Distribution of {column}')
        plt.xlabel(column)
        plt.ylabel('Frequency')
    
    plt.show()

# %%
#Check value counts
data['Free Parking'].value_counts()
# Out:
# Free Parking
# Yes    83
# No     37
# Name: count, dtype: int64

# %%
#plot pie graph
# Get value counts of 'Free Parking'
value_counts = data['Free Parking'].value_counts()

# Plotting pie chart for value counts
plt.figure(figsize=(6, 6))  # Adjust figure size if needed
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Free Parking')
plt.show()

# %%
sns.countplot(x='Free Parking',hue='Price Per Day($)',data=data)
# Out:
# <Axes: xlabel='Free Parking', ylabel='count'>

# %%
#Check value counts
data['Fitness Centre'].value_counts()
# Out:
# Fitness Centre
# No     99
# Yes    21
# Name: count, dtype: int64

# %%
#plot pie graph
# Get value counts of 'Fitness Centre'
value_counts = data['Fitness Centre'].value_counts()

# Plotting pie chart for value counts
plt.figure(figsize=(6, 6))  # Adjust figure size if needed
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Fitness Centre')
plt.show()

# %%
sns.countplot(x='Fitness Centre',hue='Price Per Day($)',data=data,palette='dark:blue')
# Out:
# <Axes: xlabel='Fitness Centre', ylabel='count'>

# %%
#Check value counts
data['Spa and Wellness Centre'].value_counts()
# Out:
# Spa and Wellness Centre
# No     104
# Yes     16
# Name: count, dtype: int64

# %%
#plot pie graph
# Get value counts of 'Spa and Wellness Centre'
value_counts = data['Spa and Wellness Centre'].value_counts()

# Plotting pie chart for value counts
plt.figure(figsize=(6, 6))  # Adjust figure size if needed
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Spa and Wellness Centre')
plt.show()

# %%
sns.countplot(x='Spa and Wellness Centre',hue='Price Per Day($)',data=data,palette='dark:red')
# Out:
# <Axes: xlabel='Spa and Wellness Centre', ylabel='count'>

# %%
#Check value counts
data['Airport Shuttle'].value_counts()
# Out:
# Airport Shuttle
# Yes    94
# No     26
# Name: count, dtype: int64

# %%
# Get value counts of Airport Shuttle
value_counts = data['Airport Shuttle'].value_counts()

# Plotting pie chart for value counts
plt.figure(figsize=(6, 6))  # Adjust figure size if needed
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Airport Shuttle')
plt.show()

# %%
sns.countplot(x='Airport Shuttle',hue='Price Per Day($)',data=data,palette='dark:green')
# Out:
# <Axes: xlabel='Airport Shuttle', ylabel='count'>

# %% [markdown]
# # Bar plot for numerical column distributions

# %%
sns.histplot(data['Star Rating'],bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data['Rating'],bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data['Staff'],bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data['Facilities'],bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data['Location'],bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data['Comfort'],bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data['Cleanliness'],bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.histplot(data['Price Per Day($)'],bins=20)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Encoding Categorical Data

# %%
categorical_features=[feature for feature in data.columns if data[feature].dtype=='O']
categorical_features
# Out:
# ['Free Parking',
#  'Fitness Centre',
#  'Spa and Wellness Centre',
#  'Airport Shuttle']

# %% [markdown]
# Label encoding in categorical columns

# %%
data.replace({'Free Parking':{'No':0,'Yes':1}},inplace=True)
data = data.infer_objects(copy=False)

# %%
data.replace({'Fitness Centre':{'No':0,'Yes':1}},inplace=True)
data = data.infer_objects(copy=False)

# %%
data.replace({'Spa and Wellness Centre':{'No':0,'Yes':1}},inplace=True)
data = data.infer_objects(copy=False)

# %%
data.replace({'Airport Shuttle':{'No':0,'Yes':1}},inplace=True)
data = data.infer_objects(copy=False)

# %%
data.head(15)
# Out:
#     Star Rating  Rating  Free Parking  Fitness Centre  \
# 0           4.0     9.7             1               0
# 1           4.0     9.3             1               0
# 2           4.0     9.5             1               0
# 3           4.0     7.4             1               0
# 4           3.0     8.2             0               0
# 5           4.0     8.8             1               0
# 6           4.0     9.0             1               0
# 7           4.0     9.2             1               0
# 8           4.0     9.0             1               0
# 9           4.0     7.2             1               0
# 10          4.0     7.8             1               0
# 11          3.0     8.8             1               0
# 12          4.0     8.2             1               0
# 13          3.0     8.1             1               0
# 14          3.0     8.7             0               0
#
#     Spa and Wellness Centre  Airport Shuttle  Staff  Facilities  Location  \
# ...

# %%
data.corr()
# Out:
#                          Star Rating    Rating  Free Parking  Fitness Centre  \
# Star Rating                 1.000000 -0.121002     -0.050168        0.438615
# Rating                     -0.121002  1.000000     -0.093904       -0.057561
# Free Parking               -0.050168 -0.093904      1.000000       -0.262389
# Fitness Centre              0.438615 -0.057561     -0.262389        1.000000
# Spa and Wellness Centre     0.369351 -0.210516     -0.003539        0.658078
# Airport Shuttle            -0.068935  0.077078      0.043072        0.082515
# Staff                      -0.168757  0.889076     -0.072787       -0.169040
# Facilities                 -0.123146  0.923100     -0.146987       -0.089726
# Location                   -0.040026  0.426284     -0.182519       -0.066867
# Comfort                    -0.074491  0.942779     -0.193690       -0.006341
# Cleanliness                -0.101458  0.928657     -0.160206       -0.035182
# ...

# %%
#feature selection
import seaborn as sns

#get correlations of each features in data set
corr_matrix = data.corr()
top_corr_features = corr_matrix.index
plt.figure(figsize=(20,20))
#plot heat map
g =sns.heatmap(data[top_corr_features].corr(),annot = True,cmap="RdYlGn")

# %%
#convert categorical data into numerical data using one-hot encoding
data = pd.get_dummies(data,columns = ['Free Parking','Fitness Centre', 'Spa and Wellness Centre','Airport Shuttle'],dtype = int)

# %%
data.head()
# Out:
#    Star Rating  Rating  Staff  Facilities  Location  Comfort  Cleanliness  \
# 0          4.0     9.7    9.9         9.8       8.8      9.7          9.8
# 1          4.0     9.3    9.7         9.4       9.7      9.2          9.2
# 2          4.0     9.5    9.8         9.5       8.9      9.4          9.5
# 3          4.0     7.4    8.1         7.3       8.3      7.5          7.8
# 4          3.0     8.2    9.1         8.0       8.3      8.1          8.2
#
#    Price Per Day($)  Free Parking_0  Free Parking_1  Fitness Centre_0  \
# 0              30.0               0               1                 1
# 1              15.0               0               1                 1
# 2              20.0               0               1                 1
# 3              26.0               0               1                 1
# 4              29.0               1               0                 1
#
#    Fitness Centre_1  Spa and Wellness Centre_0  Spa and Wellness Centre_1  \
# ...

# %%
#convert all values into one scaller
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
StandardScaler = StandardScaler()
columns_to_scale = ['Star Rating','Rating','Staff','Facilities','Location','Comfort','Cleanliness']
data[columns_to_scale] = StandardScaler.fit_transform(data[columns_to_scale])

# %%
data.tail()
# Out:
#      Star Rating    Rating     Staff  Facilities  Location   Comfort  \
# 115     2.062690 -0.396054 -0.896895   -0.076338 -0.661399 -0.197327
# 116    -1.524597  0.398260  0.254200    0.489127  0.887243  0.628692
# 117     0.269047  0.133489 -0.129498    0.262941  0.241975  0.215683
# 118     0.269047  0.927802  0.829748    0.828406 -0.790453  1.041701
# 119     0.269047 -0.263668  0.062351   -0.415616  0.887243 -0.197327
#
#      Cleanliness  Price Per Day($)  Free Parking_0  Free Parking_1  \
# 115    -0.190024             118.0               0               1
# 116     0.605425             102.0               1               0
# 117     0.207700             118.0               0               1
# 118     1.003149              50.0               1               0
# 119    -0.322599              85.0               0               1
#
#      Fitness Centre_0  Fitness Centre_1  Spa and Wellness Centre_0  \
# 115                 0                 1                          0
# ...

# %% [markdown]
# # Model Building

# %%
#select features in x and y
x = data.drop('Price Per Day($)',axis=1)
y = data['Price Per Day($)']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# Display the shapes of the resulting datasets
print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# x_train shape: (96, 15)
# x_test shape: (24, 15)
# y_train shape: (96,)
# y_test shape: (24,)

# %% [markdown]
# In this problem is Regression problem.So we use Linear Regression Algorithem.

# %%
#import necessary algorithems
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import metrics

# loading the linear regression model
lin_reg_model = LinearRegression()
lin_reg_model.fit(x_train, y_train)

# Making predictions
y_train_pred = lin_reg_model.predict(x_train)
y_test_pred = lin_reg_model.predict(x_test)


# Calculating Mean Squared Error (MSE)
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

# Calculating R-squared (R²) for accuracy
train_r2 = metrics.r2_score(y_train, y_train_pred)
test_r2 = r2_score(y_test, y_test_pred)


# Displaying the results
print(f"Training MSE: {train_mse}")
print(f"Test MSE: {test_mse}")
print(f"Training R²: {train_r2}")
print(f"Test R²: {test_r2}")
# Out:
# Training MSE: 2801.5374211317408
# Test MSE: 1666.341236595789
# Training R²: 0.3241035257903646
# Test R²: 0.1560358717177458

# %%
# The line of best fit for training data
m, b = np.polyfit(y_train, y_train_pred, 1)
plt.plot(y_train, m*y_train + b, color='red', label='Regression Line (Train)')

plt.scatter(y_train, y_train_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
# The line of best fit for training data
m, b = np.polyfit(y_test, y_test_pred, 1)
plt.plot(y_train, m*y_train + b, color='red', label='Regression Line (Train)')

plt.scatter(y_test, y_test_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
x_train.columns
# Out:
# Index(['Star Rating', 'Rating', 'Staff', 'Facilities', 'Location', 'Comfort',
#        'Cleanliness', 'Free Parking_0', 'Free Parking_1', 'Fitness Centre_0',
#        'Fitness Centre_1', 'Spa and Wellness Centre_0',
#        'Spa and Wellness Centre_1', 'Airport Shuttle_0', 'Airport Shuttle_1'],
#       dtype='object')

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.38530588375898667

# %%
import pickle
with open("Hotel_Price_predictor.pickle",'wb') as file:
    pickle.dump(mo,file)
